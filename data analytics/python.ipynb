# %%
class node:
    def __init__(self,data):
        self.data=data
        self.next=none
node.add(10)
node.add(20)
node.add(30)
node.add(40)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 5
#       3         self.data=data
#       4         self.next=none
# ----> 5 node.add(10)
#       6 node.add(20)
#       7 node.add(30)
#
# AttributeError: type object 'node' has no attribute 'add'
